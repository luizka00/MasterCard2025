# %%
import pandas as pd

# %%
df = pd.read_csv("merchants.csv")

# %%
df
# Out:
#     merchant_id     category         country  trust_score  \
# 0         M0001       travel         Austria     1.000000
# 1         M0002     clothing          Poland     0.689695
# 2         M0003  electronics  Czech Republic     0.834610
# 3         M0004  electronics         Belgium     0.607229
# 4         M0005      grocery         Ireland     0.641901
# ..          ...          ...             ...          ...
# 995       M0996       travel          France     0.412610
# 996       M0997     clothing         Ireland     0.616576
# 997       M0998    education         Finland     0.673047
# 998       M0999  electronics        Portugal     0.738578
# 999       M1000    education     Netherlands     0.879709
#
#      number_of_alerts_last_6_months  avg_transaction_amount  \
# 0                                 3                   97.23
# 1                                 2                  142.71
# 2                                 5                   67.83
# ...

# %%
df1 = pd.read_csv("users.csv")

# %%
df1
# Out:
#       user_id  age     sex    education primary_source_of_income  \
# 0      U00001   56   Other  High School               Employment
# 1      U00002   36  Female     Bachelor                 Business
# 2      U00003   70   Other  High School              Student Aid
# 3      U00004   38   Other  High School                  Savings
# 4      U00005   61    Male  High School               Employment
# ...       ...  ...     ...          ...                      ...
# 19995  U19996   38   Other     Bachelor               Employment
# 19996  U19997   18   Other  High School              Student Aid
# 19997  U19998   53   Other          NaN             Unemployment
# 19998  U19999   47   Other       Master               Retirement
# 19999  U20000   50  Female          NaN             Unemployment
#
#        sum_of_monthly_installments  sum_of_monthly_expenses   country  \
# 0                           477.69                   243.18   Finland
# ...

# %%
df2 = pd.read_json("transactions.json", lines=True)

# %%
df2
# Out:
#        transaction_id           timestamp user_id merchant_id  amount  \
# 0            TX000000 2022-06-17 23:28:00  U14804       M0314  130.03
# 1            TX000001 2022-01-04 15:39:00  U16634       M0675  132.00
# 2            TX000002 2022-09-09 21:58:00  U18005       M0479    8.65
# 3            TX000003 2023-11-20 06:40:00  U13690       M0538   19.82
# 4            TX000004 2022-04-28 08:08:00  U04642       M0128  101.92
# ...               ...                 ...     ...         ...     ...
# 499995       TX499995 2022-04-19 18:12:00  U00062       M0079   11.53
# 499996       TX499996 2023-06-02 06:59:00  U17320       M0760   78.01
# 499997       TX499997 2022-08-06 13:14:00  U07750       M0215   77.65
# 499998       TX499998 2023-03-20 22:00:00  U14492       M0848  221.38
# 499999       TX499999 2023-01-29 14:46:00  U11248       M0075  103.17
#
#          channel currency   device                               location  \
# ...
